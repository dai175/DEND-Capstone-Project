# %% [markdown]
# # Project Title
# ### Data Engineering Capstone Project
#
# #### Project Summary
# --describe your project at a high level--
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
import configparser
import os
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')

os.environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']

output_data = config['S3']['S3_BUCKET']

# %%
spark = SparkSession.builder \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
    .enableHiveSupport() \
    .getOrCreate()
spark._jsc.hadoopConfiguration().set("mapreduce.fileoutputcommitter.algorithm.version", "2")

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# In this project, we will use the I94 Immigration Data and the Airport Code Table to create data that merges both pieces of information. This data can, for example, tell us the name of the airport the immigrant came from. I will use Pyspark to accomplish this process.
#
# #### Describe and Gather Data
# - I94 Immigration Data: This data comes from the US National Tourism and Trade Office. A data dictionary is included in the workspace. This is where the data comes from. There's a sample file so you can take a look at the data in csv format before reading it all in. You do not have to use the entire dataset, just use what you need to accomplish the goal you set at the beginning of the project.
#
# - Airport Code Table: This is a simple table of airport codes and corresponding cities. It comes from here.

# %% [markdown]
# ##### I94 Immigration Data

# %%
df_immigration = spark.read.load('./sas_data')
df_immigration.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- count: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- visapost: string (nullable = true)
#  |-- occup: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- entdepu: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- insnum: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: double (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
df_immigration.limit(5).toPandas().head()
# Out:
#        cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  \
# 0  5748517.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 1  5748518.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 2  5748519.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 3  5748520.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 4  5748521.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
#
#   i94addr  depdate   ...     entdepu  matflag  biryear   dtaddto gender  \
# 0      CA  20582.0   ...        None        M   1976.0  10292016      F
# 1      NV  20591.0   ...        None        M   1984.0  10292016      F
# 2      WA  20582.0   ...        None        M   1987.0  10292016      M
# 3      WA  20588.0   ...        None        M   1987.0  10292016      F
# 4      WA  20588.0   ...        None        M   1988.0  10292016      M
#
#   insnum airline        admnum  fltno visatype
# 0   None      QF  9.495387e+10  00011       B1
# 1   None      VA  9.495562e+10  00007       B1
# 2   None      DL  9.495641e+10  00040       B1
# 3   None      DL  9.495645e+10  00040       B1
# 4   None      DL  9.495639e+10  00040       B1
#
# [5 rows x 28 columns]

# %%
df_immigration.show()
# Out:
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |    cicid| i94yr|i94mon|i94cit|i94res|i94port|arrdate|i94mode|i94addr|depdate|i94bir|i94visa|count|dtadfile|visapost|occup|entdepa|entdepd|entdepu|matflag|biryear| dtaddto|gender|insnum|airline|        admnum|fltno|visatype|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |5748517.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     CA|20582.0|  40.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1976.0|10292016|     F|  null|     QF|9.495387003E10|00011|      B1|
# |5748518.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     NV|20591.0|  32.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1984.0|10292016|     F|  null|     VA|9.495562283E10|00007|      B1|
# |5748519.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20582.0|  29.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1987.0|10292016|     M|  null|     DL|9.495640653E10|00040|      B1|
# |5748520.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  29.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1987.0|10292016|     F|  null|     DL|9.495645143E10|00040|      B1|
# |5748521.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  28.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1988.0|10292016|     M|  null|     DL|9.495638813E10|00040|      B1|
# |5748522.0|2016.0|   4.0| 245.0| 464.0|    HHW|20574.0|    1.0|     HI|20579.0|  57.0|    2.0|  1.0|20160430|     ACK| null|      G|      O|   null|      M| 1959.0|10292016|     M|  null|     NZ|9.498180283E10|00010|      B2|
# |5748523.0|2016.0|   4.0| 245.0| 464.0|    HHW|20574.0|    1.0|     HI|20586.0|  66.0|    2.0|  1.0|20160430|     ACK| null|      G|      O|   null|      M| 1950.0|10292016|     F|  null|     NZ|9.497968993E10|00010|      B2|
# |5748524.0|2016.0|   4.0| 245.0| 464.0|    HHW|20574.0|    1.0|     HI|20586.0|  41.0|    2.0|  1.0|20160430|     ACK| null|      G|      O|   null|      M| 1975.0|10292016|     F|  null|     NZ|9.497974673E10|00010|      B2|
# |5748525.0|2016.0|   4.0| 245.0| 464.0|    HOU|20574.0|    1.0|     FL|20581.0|  27.0|    2.0|  1.0|20160430|     ACK| null|      G|      O|   null|      M| 1989.0|10292016|     M|  null|     NZ|9.497324663E10|00028|      B2|
# |5748526.0|2016.0|   4.0| 245.0| 464.0|    LOS|20574.0|    1.0|     CA|20581.0|  26.0|    2.0|  1.0|20160430|     ACK| null|      G|      O|   null|      M| 1990.0|10292016|     F|  null|     NZ|9.501354793E10|00002|      B2|
# |5748527.0|2016.0|   4.0| 245.0| 504.0|    NEW|20574.0|    1.0|     MA|20576.0|  44.0|    2.0|  1.0|20160430|     GUZ| null|      G|      O|   null|      M| 1972.0|10292016|     M|  null|     UA|9.493828593E10|01215|      B2|
# |5748528.0|2016.0|   4.0| 245.0| 504.0|    LOS|20574.0|    1.0|   null|20575.0|  39.0|    2.0|  1.0|20160430|     GUZ| null|      G|      O|   null|      M| 1977.0|10292016|     M|  null|     CM|9.501810463E10|00472|      B2|
# |5748529.0|2016.0|   4.0| 245.0| 504.0|    WAS|20574.0|    1.0|     VA|20596.0|  38.0|    2.0|  1.0|20160430|     PNM| null|      G|      O|   null|      M| 1978.0|10292016|     M|  null|     CM|9.492489983E10|00488|      B2|
# |5748530.0|2016.0|   4.0| 245.0| 504.0|    LOS|20574.0|    1.0|     CA|20577.0|  56.0|    2.0|  1.0|20160430|     PNM| null|      G|      O|   null|      M| 1960.0|10292016|     F|  null|     CM|9.492648103E10|00302|      B2|
# |5748531.0|2016.0|   4.0| 245.0| 504.0|    LOS|20574.0|    1.0|     CA|20577.0|  38.0|    2.0|  1.0|20160430|     PNM| null|      G|      O|   null|      M| 1978.0|10282016|     M|  null|     CM|9.492629303E10|00302|      B2|
# |5748532.0|2016.0|   4.0| 245.0| 504.0|    MIA|20574.0|    1.0|     FL|20581.0|  53.0|    2.0|  1.0|20160430|     PNM| null|      G|      O|   null|      M| 1963.0|10292016|     F|  null|     CM|9.500640513E10|00430|      B2|
# |5748534.0|2016.0|   4.0| 245.0| 528.0|    SFR|20574.0|    1.0|     CA|   null|  84.0|    2.0|  1.0|20160430|     HNK| null|      G|   null|   null|   null| 1932.0|10282016|     F|  null|     CX|9.492476223E10|00872|      B2|
# |5748876.0|2016.0|   4.0| 245.0| 582.0|    HOU|20574.0|    1.0|     TX|20583.0|  43.0|    1.0|  1.0|20160430|     GUZ| null|      G|      O|   null|      M| 1973.0|10292016|     M|  null|     UA|9.499463063E10|05574|      B1|
# |5748877.0|2016.0|   4.0| 245.0| 582.0|    HOU|20574.0|    1.0|     TX|20583.0|  30.0|    1.0|  1.0|20160430|     GUZ| null|      G|      O|   null|      M| 1986.0|10292016|     F|  null|     UA|9.499447663E10|05574|      B1|
# |5748881.0|2016.0|   4.0| 245.0| 582.0|    LOS|20574.0|    1.0|     CA|20575.0|  34.0|    2.0|  1.0|20160430|     SHG| null|      G|      O|   null|      M| 1982.0|10292016|     M|  null|     AM|9.496770903E10|00646|      B2|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# only showing top 20 rows

# %%
df_immigration.count()
# Out:
# 3096313

# %% [markdown]
# ##### Airport Code Table

# %%
df_airport = spark.read.csv('airport-codes_csv.csv', header=True)
df_airport.printSchema()
# Out:
# root
#  |-- ident: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- elevation_ft: string (nullable = true)
#  |-- continent: string (nullable = true)
#  |-- iso_country: string (nullable = true)
#  |-- iso_region: string (nullable = true)
#  |-- municipality: string (nullable = true)
#  |-- gps_code: string (nullable = true)
#  |-- iata_code: string (nullable = true)
#  |-- local_code: string (nullable = true)
#  |-- coordinates: string (nullable = true)

# %%
df_airport.limit(5).toPandas().head()
# Out:
#   ident           type                                name elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport           11
# 1  00AA  small_airport                Aero B Ranch Airport         3435
# 2  00AK  small_airport                        Lowell Field          450
# 3  00AL  small_airport                        Epps Airpark          820
# 4  00AR         closed  Newport Hospital & Clinic Heliport          237
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0        NA          US      US-PA      Bensalem      00A      None
# 1        NA          US      US-KS         Leoti     00AA      None
# 2        NA          US      US-AK  Anchor Point     00AK      None
# 3        NA          US      US-AL       Harvest     00AL      None
# 4        NA          US      US-AR       Newport     None      None
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4       None                    -91.254898, 35.6087

# %%
df_airport.count()
# Out:
# 55075

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %% [markdown]
# ##### I94 Immigration Data

# %% [markdown]
# Check that there are no null values in the key items to be merged with the Airport Code Table, and check the contents of the code.

# %%
df_immigration.filter(df_immigration['i94port'].isNull()).count()
# Out:
# 0

# %%
df_immigration.select(df_immigration['i94port']).drop_duplicates().toPandas()
# Out:
#     i94port
# 0       FMY
# 1       BGM
# 2       HEL
# 3       DNS
# 4       MOR
# 5       FOK
# 6       HVR
# 7       SNA
# 8       PTK
# 9       CLG
# 10      SPM
# 11      OPF
# 12      DLB
# 13      ABS
# 14      NAS
# 15      MYR
# 16      PVD
# 17      OAK
# 18      FAR
# 19      OTT
# 20      PBB
# 21      WAR
# 22      CRY
# 23      NRN
# 24      DET
# 25      FRT
# 26      NOO
# 27      REN
# 28      BEE
# 29      AGN
# ..      ...
# 269     EPI
# 270     BEL
# 271     ONT
# 272     JKM
# 273     FWA
# 274     MDT
# 275     SNJ
# 276     BLA
# 277     ANZ
# 278     ROC
# 279     CHI
# 280     PRE
# 281     W55
# 282     LEW
# 283     FPR
# 284     BAU
# 285     FER
# 286     DAB
# 287     ANC
# 288     OGG
# 289     5T6
# 290     BEB
# 291     ORL
# 292     SLC
# 293     SHR
# 294     NYC
# 295     STT
# 296     MND
# 297     SAI
# 298     MIL
#
# [299 rows x 1 columns]

# %% [markdown]
# ##### Airport Code Table

# %% [markdown]
# Check that there are no null values in the key items to be merged with the Airport Code Table, and check the contents of the code.
# Delete the data with null values.

# %%
df_airport_cleaned = df_airport.filter(df_airport["iso_country"]=="US")
df_airport_cleaned.count()
# Out:
# 22757

# %%
df_airport_cleaned.filter(df_airport_cleaned["iata_code"].isNull()).count()
# Out:
# 20738

# %%
df_airport_cleaned = df_airport_cleaned.filter(df_airport_cleaned["iata_code"].isNotNull())
df_airport_cleaned.count()
# Out:
# 2019

# %%
df_airport_cleaned.drop_duplicates(['iata_code']).count()
# Out:
# 2014

# %%
df_airport_cleaned = df_airport_cleaned.drop_duplicates(['iata_code'])
df_airport_cleaned.count()
# Out:
# 2014

# %%
df_airport_cleaned.toPandas()
# Out:
#      ident            type                                               name  \
# 0     KBGM  medium_airport              Greater Binghamton/Edwin A Link field
# 1     2TE0   small_airport                                     Eagle Air Park
# 2     KCNU  medium_airport                     Chanute Martin Johnson Airport
# 3     KCRS   small_airport  C David Campbell Field Corsicana Municipal Air...
# 4     KFMY  medium_airport                                         Page Field
# 5      HYL   seaplane_base                     Hollis Clark Bay Seaplane Base
# 6      KEB   small_airport                                   Nanwalek Airport
# 7     KLEB  medium_airport                          Lebanon Municipal Airport
# 8     KOXC   small_airport                           Waterbury Oxford Airport
# 9     KRKP   small_airport                             Aransas County Airport
# 10    KSGT   small_airport  Stuttgart Municipal Airport / Carl Humphrey Field
# 11     SKJ          closed                                   Sitkinak Airport
# 12    KTNP   small_airport                           Twentynine Palms Airport
# 13    KAIV   small_airport                              George Downer Airport
# 14    KAVX   small_airport                                   Catalina Airport
# 15    PADL  medium_airport                                 Dillingham Airport
# 16    KDNS   small_airport                          Denison Municipal Airport
# 17    PFEL   small_airport                                       Elim Airport
# 18    KFCY   small_airport                     Forrest City Municipal Airport
# 19    AZ15        heliport                                Lava Falls Heliport
# 20    KIML   small_airport                         Imperial Municipal Airport
# 21    KINL  medium_airport                        Falls International Airport
# 22    KOLF  medium_airport                                L M Clayton Airport
# 23     TYE   small_airport                                     Tyonek Airport
# 24     BNF   seaplane_base       Baranof Warm Springs Float and Seaplane Base
# 25    PAFR        heliport                               Bryant Army Heliport
# 26    KMSY   large_airport  Louis Armstrong New Orleans International Airport
# 27    KONO   small_airport                          Ontario Municipal Airport
# 28    KRDG  medium_airport               Reading Regional Carl A Spaatz Field
# 29    KRHV   small_airport        Reid-Hillview Airport of Santa Clara County
# ...    ...             ...                                                ...
# 1984  KRPX   small_airport                                    Roundup Airport
# 1985  KRQO   small_airport                           El Reno Regional Airport
# 1986  KSAT   large_airport                  San Antonio International Airport
# 1987  KSHR  medium_airport                            Sheridan County Airport
# 1988  KSLC   large_airport               Salt Lake City International Airport
# 1989  KEUF   small_airport                                       Weedon Field
# 1990  KHBR  medium_airport                            Hobart Regional Airport
# 1991   KBE   seaplane_base              Bell Island Hot Springs Seaplane Base
# 1992  KMLC  medium_airport                        Mc Alester Regional Airport
# 1993  KMTO   small_airport                      Coles County Memorial Airport
# 1994  KPSN   small_airport                        Palestine Municipal Airport
# 1995  KSFZ   small_airport                        North Central State Airport
# 1996  KSKY          closed                          Griffing Sandusky Airport
# 1997  KTCL  medium_airport                        Tuscaloosa Regional Airport
# 1998  KTOA   small_airport                                    Zamperini Field
# 1999  PAFM  medium_airport                                     Ambler Airport
# 2000   ARX          closed                   Asbury Park Neptune Air Terminal
# 2001  KASE  medium_airport                        Aspen-Pitkin Co/Sardy Field
# 2002  KCRQ  medium_airport                         Mc Clellan-Palomar Airport
# 2003  KCLR   small_airport                    Cliff Hatfield Memorial Airport
# 2004  KCPS   small_airport                          St Louis Downtown Airport
# 2005  KFCS  medium_airport                  Butts AAF (Fort Carson) Air Field
# 2006  KFLP   small_airport                     Marion County Regional Airport
# 2007  KHKY  medium_airport                           Hickory Regional Airport
# 2008  KLEE  medium_airport                     Leesburg International Airport
# 2009  KRAP  medium_airport                        Rapid City Regional Airport
# 2010  KSBP  medium_airport                   San Luis County Regional Airport
# 2011  PASH  medium_airport                                 Shishmaref Airport
# 2012  KSUS   large_airport                         Spirit of St Louis Airport
# 2013  KUKT   small_airport                                 Quakertown Airport
#
#      elevation_ft continent iso_country iso_region  \
# 0            1636        NA          US      US-NY
# 1              15        NA          US      US-TX
# 2            1002        NA          US      US-KS
# 3             449        NA          US      US-TX
# 4              17        NA          US      US-FL
# 5               0        NA          US      US-AK
# 6              27        NA          US      US-AK
# 7             603        NA          US      US-NH
# 8             726        NA          US      US-CT
# 9              24        NA          US      US-TX
# 10            224        NA          US      US-AR
# 11             65        NA          US      US-AK
# 12           1888        NA          US      US-CA
# 13            150        NA          US      US-AL
# 14           1602        NA          US      US-CA
# 15             81        NA          US      US-AK
# 16           1274        NA          US      US-IA
# 17            162        NA          US      US-AK
# 18            249        NA          US      US-AR
# 19           1720        NA          US      US-AZ
# 20           3275        NA          US      US-NE
# 21           1185        NA          US      US-MN
# 22           1986        NA          US      US-MT
# 23            110        NA          US      US-AK
# 24              0        NA          US      US-AK
# 25            378        NA          US      US-AK
# 26              4        NA          US      US-LA
# 27           2193        NA          US      US-OR
# 28            344        NA          US      US-PA
# 29            135        NA          US      US-CA
# ...           ...       ...         ...        ...
# 1984         3500        NA          US      US-MT
# 1985         1420        NA          US      US-OK
# 1986          809        NA          US      US-TX
# 1987         4021        NA          US      US-WY
# 1988         4227        NA          US      US-UT
# 1989          285        NA          US      US-AL
# 1990         1563        NA          US      US-OK
# 1991         None        NA          US      US-AK
# 1992          770        NA          US      US-OK
# 1993          722        NA          US      US-IL
# 1994          423        NA          US      US-TX
# 1995          441        NA          US      US-RI
# 1996          580        NA          US      US-OH
# 1997          170        NA          US      US-AL
# 1998          103        NA          US      US-CA
# 1999          334        NA          US      US-AK
# 2000           95        NA          US      US-NJ
# 2001         7820        NA          US      US-CO
# 2002          331        NA          US      US-CA
# 2003         -182        NA          US      US-CA
# 2004          413        NA          US      US-IL
# 2005         5838        NA          US      US-CO
# 2006          719        NA          US      US-AR
# 2007         1190        NA          US      US-NC
# 2008           76        NA          US      US-FL
# 2009         3204        NA          US      US-SD
# 2010          212        NA          US      US-CA
# 2011           12        NA          US      US-AK
# 2012          463        NA          US      US-MO
# 2013          526        NA          US      US-PA
#
#                     municipality gps_code iata_code local_code  \
# 0                     Binghamton     KBGM       BGM        BGM
# 1                       Brazoria     2TE0       BZT       2TE0
# 2                        Chanute     KCNU       CNU        CNU
# 3                      Corsicana     KCRS       CRS        CRS
# 4                     Fort Myers     KFMY       FMY        FMY
# 5                         Hollis      HYL       HYL        HYL
# 6                       Nanwalek      KEB       KEB        KEB
# 7                        Lebanon     KLEB       LEB        LEB
# 8                         Oxford     KOXC       OXC        OXC
# 9                       Rockport     KRKP       RKP        RKP
# 10                     Stuttgart     KSGT       SGT        SGT
# 11               Sitkinak Island     None       SKJ        SKJ
# 12              Twentynine Palms     KTNP       TNP        TNP
# 13                    Aliceville     KAIV       AIV        AIV
# 14                        Avalon     KAVX       AVX        AVX
# 15                    Dillingham     PADL       DLG        DLG
# 16                       Denison     KDNS       DNS        DNS
# 17                          Elim     PFEL       ELI        ELI
# 18                  Forrest City     KFCY       FCY        FCY
# 19                 Supai Village     AZ15       HAE       AZ15
# 20                      Imperial     KIML       IML        IML
# 21           International Falls     KINL       INL        INL
# 22                    Wolf Point     KOLF       OLF        OLF
# 23                        Tyonek      TYE       TYE        TYE
# 24                       Baranof     None       BNF        BNF
# 25    Fort Richardson(Anchorage)     PAFR       FRN        FRN
# 26                   New Orleans     KMSY       MSY        MSY
# 27                       Ontario     KONO       ONO        ONO
# 28                       Reading     KRDG       RDG        RDG
# 29                      San Jose     KRHV       RHV        RHV
# ...                          ...      ...       ...        ...
# 1984                     Roundup     KRPX       RPX        RPX
# 1985                     El Reno     KRQO       RQO        RQO
# 1986                 San Antonio     KSAT       SAT        SAT
# 1987                    Sheridan     KSHR       SHR        SHR
# 1988              Salt Lake City     KSLC       SLC        SLC
# 1989                     Eufaula     KEUF       EUF        EUF
# 1990                      Hobart     KHBR       HBR        HBR
# 1991                 Bell Island      KBE       KBE        KBE
# 1992                  Mc Alester     KMLC       MLC        MLC
# 1993          Mattoon/Charleston     KMTO       MTO        MTO
# 1994                   Palestine     KPSN       PSN        PSN
# 1995                   Pawtucket     KSFZ       SFZ        SFZ
# 1996                    Sandusky     KSKY       SKY        SKY
# 1997                  Tuscaloosa     KTCL       TCL        TCL
# 1998                    Torrance     KTOA       TOA        TOA
# 1999                      Ambler     PAFM       ABL        AFM
# 2000                 Asbury Park     None       ARX       None
# 2001                       Aspen     KASE       ASE        ASE
# 2002                    Carlsbad     KCRQ       CLD        CRQ
# 2003                  Calipatria     KCLR       CLR        CLR
# 2004            Cahokia/St Louis     KCPS       CPS        CPS
# 2005                 Fort Carson     KFCS       FCS        FCS
# 2006                     Flippin     KFLP       FLP        FLP
# 2007                     Hickory     KHKY       HKY        HKY
# 2008                    Leesburg     KLEE       LEE        LEE
# 2009                  Rapid City     KRAP       RAP        RAP
# 2010             San Luis Obispo     KSBP       SBP        SBP
# 2011                  Shishmaref     PASH       SHH        SHH
# 2012                    St Louis     KSUS       SUS        SUS
# 2013                  Quakertown     KUKT       UKT        UKT
#
#                                  coordinates
# 0                  -75.97979736, 42.20869827
# 1          -95.579696655273, 28.982200622559
# 2               -95.4850997925, 37.668800354
# 3              -96.4005966187, 32.0280990601
# 4            -81.86329650879999, 26.58659935
# 5              -132.645996094, 55.4816017151
# 6              -151.925003052, 59.3521003723
# 7     -72.30419921880001, 43.626098632799994
# 8           -73.135200500488, 41.47859954834
# 9              -97.0446014404, 28.0867996216
# 10                     -91.574997, 34.599499
# 11                        -154.1412, 56.5378
# 12                 -115.9459991, 34.13159943
# 13                       -88.1978, 33.106499
# 14                         -118.416, 33.4049
# 15                 -158.5050049, 59.04470062
# 16                  -95.38069916, 41.9864006
# 17                 -162.2720032, 64.61470032
# 18        -90.7750015259, 34.942001342800005
# 19        -113.092002869, 36.191600799599996
# 20                 -101.6210022, 40.50930023
# 21     -93.4030990600586, 48.566200256347656
# 22        -105.574996948, 48.094501495399996
# 23         -151.13800048828, 61.076698303223
# 24                    -134.833146, 57.088799
# 25                 -149.6529999, 61.26639938
# 26     -90.25800323486328, 29.99340057373047
# 27         -117.01399993896, 44.020500183105
# 28    -75.96520233154297, 40.378501892089844
# 29              -121.819000244, 37.332901001
# ...                                      ...
# 1984                  -108.541497, 46.475095
# 1985               -98.00579834, 35.47269821
# 1986  -98.46980285644531, 29.533700942993164
# 1987   -106.9800033569336, 44.76919937133789
# 1988  -111.97799682617188, 40.78839874267578
# 1989           -85.1288986206, 31.9512996674
# 1990                   -99.051313, 34.991317
# 1991           -131.572006226, 55.9291000366
# 1992                   -95.783501, 34.882401
# 1993                   -88.279198, 39.477901
# 1994       -95.706298828125, 31.779699325562
# 1995       -71.49140167239999, 41.9207992554
# 1996           -82.6522979736, 41.4333992004
# 1997       -87.611396789551, 33.220600128174
# 1998       -118.33999633789, 33.803398132324
# 1999                    -157.856989, 67.1063
# 2000           -74.0908333333, 40.2193055556
# 2001               -106.8690033, 39.22320175
# 2002               -117.2799988, 33.12829971
# 2003      -115.521003723, 33.131500244099996
# 2004      -90.1561965942, 38.570701599100005
# 2005               -104.7570038, 38.67839813
# 2006               -92.59030151, 36.29090118
# 2007               -81.38950348, 35.74110031
# 2008               -81.80870056, 28.82309914
# 2009   -103.05699920654297, 44.0452995300293
# 2010      -120.641998291, 35.236801147499996
# 2011                  -166.089112, 66.249604
# 2012       -90.652000427246, 38.662101745605
# 2013       -75.381896972656, 40.435199737549
#
# [2014 rows x 12 columns]

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# I94 Immigration Data
#
# Select only meaningful items from the original data.
# Also, date items are converted from Julian to Gregorian calendar.
#
# - i94yr
# - i94mon
# - i94port
# - arrdate
# - i94addr
# - depdate
# - i94bir
# - i94visa
# - biryear
# - gender
# - airline
# - admnum
# - fltno
# - visatype
#
# Airport Code Table
#
# Split coordinates into latitude and longitude.
#
# - cicid
# - ident
# - type
# - name
# - elevation_ft
# - continent
# - iso_country
# - iso_region
# - municipality
# - gps_code
# - iata_code
# - local_code
# - latitude
# - longitude
#
# #### 3.2 Mapping Out Data Pipelines
#
# I94 Immigration Data
#
# - Add items that converts arrdate and depdate to Gregorian calender.
# - Extract selected items.
#
# Airport Code Table
#
# - Add the latitude and longitude where the coordinates are divided.
# - Extract selected items.

# %% [markdown]
# ##### I94 Immigration Data

# %%
from datetime import datetime
from datetime import timedelta
from pyspark.sql.functions import udf
from pyspark.sql.types import DateType

def convert_datetime(num_days):
    try:
        start = datetime(1960, 1, 1)
        return start + timedelta(days=int(num_days))
    except:
        return None
    
udf_datetime_from_sas = udf(lambda x: convert_datetime(x), DateType())
df_immigration_new = df_immigration \
    .withColumn("arrival_date", udf_datetime_from_sas("arrdate")) \
    .withColumn("departure_date", udf_datetime_from_sas("depdate"))

# %%
immigration_table = df_immigration_new.select(
    col("cicid").cast("int"),
    col("i94yr").cast("int"),
    col("i94mon").cast("int"),
    col("i94port"),
    col("arrival_date").alias("arrdate"),
    col("i94addr"),
    col("departure_date").alias("depdate"),
    col("i94bir").cast("int"),
    col("i94visa").cast("int"),
    col("biryear").cast("int"),
    col("gender"),
    col("airline"),
    col("admnum").cast("int"),
    col("fltno"),
    col("visatype")
)
immigration_table.limit(5).toPandas().head()
# Out:
#      cicid  i94yr  i94mon i94port     arrdate i94addr     depdate  i94bir  \
# 0  5748517   2016       4     LOS  2016-04-30      CA  2016-05-08      40
# 1  5748518   2016       4     LOS  2016-04-30      NV  2016-05-17      32
# 2  5748519   2016       4     LOS  2016-04-30      WA  2016-05-08      29
# 3  5748520   2016       4     LOS  2016-04-30      WA  2016-05-14      29
# 4  5748521   2016       4     LOS  2016-04-30      WA  2016-05-14      28
#
#    i94visa  biryear gender airline      admnum  fltno visatype
# 0        1     1976      F      QF  2147483647  00011       B1
# 1        1     1984      F      VA  2147483647  00007       B1
# 2        1     1987      M      DL  2147483647  00040       B1
# 3        1     1987      F      DL  2147483647  00040       B1
# 4        1     1988      M      DL  2147483647  00040       B1

# %%
immigration_table.count()
# Out:
# 3096313

# %%
immigration_table.write.partitionBy("i94yr", "i94mon").mode('overwrite').parquet(os.path.join(output_data, 'immigration'))

# %% [markdown]
# ##### Airport Code Table

# %%
df_airport_new = df_airport_cleaned \
    .withColumn('latitude', split(df_airport_cleaned['coordinates'], ',').getItem(0)) \
    .withColumn('longitude', split(df_airport_cleaned['coordinates'], ',').getItem(1))

airport_table = df_airport_new.select(
    col("ident"),
    col("type"),
    col("name"),
    col("elevation_ft").cast("int"),
    col("continent"),
    col("iso_country"),
    col("iso_region"),
    col("municipality"),
    col("gps_code"),
    col("iata_code"),
    col("local_code"),
    col("latitude").cast("float"),
    col("longitude").cast("float")
)
airport_table.limit(5).toPandas().head()
# Out:
#   ident            type                                               name  \
# 0  KBGM  medium_airport              Greater Binghamton/Edwin A Link field
# 1  2TE0   small_airport                                     Eagle Air Park
# 2  KCNU  medium_airport                     Chanute Martin Johnson Airport
# 3  KCRS   small_airport  C David Campbell Field Corsicana Municipal Air...
# 4  KFMY  medium_airport                                         Page Field
#
#    elevation_ft continent iso_country iso_region municipality gps_code  \
# 0          1636        NA          US      US-NY   Binghamton     KBGM
# 1            15        NA          US      US-TX     Brazoria     2TE0
# 2          1002        NA          US      US-KS      Chanute     KCNU
# 3           449        NA          US      US-TX    Corsicana     KCRS
# 4            17        NA          US      US-FL   Fort Myers     KFMY
#
#   iata_code local_code   latitude  longitude
# 0       BGM        BGM -75.979797  42.208698
# 1       BZT       2TE0 -95.579697  28.982201
# 2       CNU        CNU -95.485100  37.668800
# 3       CRS        CRS -96.400597  32.028099
# 4       FMY        FMY -81.863297  26.586599

# %%
airport_table.count()
# Out:
# 2014

# %%
airport_table.coalesce(1).write.mode('overwrite').parquet(os.path.join(output_data, 'airport'))

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %% [markdown]
# ##### I94 Immigration Data

# %%
df_immigration_step4 = spark.read.parquet(os.path.join(output_data, 'immigration'))

# %%
df_immigration_step4.limit(5).toPandas().head()
# Out:
#      cicid i94port     arrdate i94addr     depdate  i94bir  i94visa  biryear  \
# 0  5748517     LOS  2016-04-30      CA  2016-05-08      40        1     1976
# 1  3344386     NEW  2016-04-17      NJ  2016-04-25      67        2     1949
# 2  5748518     LOS  2016-04-30      NV  2016-05-17      32        1     1984
# 3  3344387     NEW  2016-04-17      NJ  2016-04-25      49        2     1967
# 4  5748519     LOS  2016-04-30      WA  2016-05-08      29        1     1987
#
#   gender airline      admnum  fltno visatype  i94yr  i94mon
# 0      F      QF  2147483647  00011       B1   2016       4
# 1      M      UA  2147483647  00865       WT   2016       4
# 2      F      VA  2147483647  00007       B1   2016       4
# 3      F      UA  2147483647  00865       WT   2016       4
# 4      M      DL  2147483647  00040       B1   2016       4

# %%
df_immigration_step4.count()
# Out:
# 3096313

# %% [markdown]
# ##### Airport Code Table

# %%
df_airport_step4 = spark.read.parquet(os.path.join(output_data, 'airport'))

# %%
df_airport_step4.limit(5).toPandas().head()
# Out:
#   ident            type                                               name  \
# 0  KBGM  medium_airport              Greater Binghamton/Edwin A Link field
# 1  2TE0   small_airport                                     Eagle Air Park
# 2  KCNU  medium_airport                     Chanute Martin Johnson Airport
# 3  KCRS   small_airport  C David Campbell Field Corsicana Municipal Air...
# 4  KFMY  medium_airport                                         Page Field
#
#    elevation_ft continent iso_country iso_region municipality gps_code  \
# 0          1636        NA          US      US-NY   Binghamton     KBGM
# 1            15        NA          US      US-TX     Brazoria     2TE0
# 2          1002        NA          US      US-KS      Chanute     KCNU
# 3           449        NA          US      US-TX    Corsicana     KCRS
# 4            17        NA          US      US-FL   Fort Myers     KFMY
#
#   iata_code local_code   latitude  longitude
# 0       BGM        BGM -75.979797  42.208698
# 1       BZT       2TE0 -95.579697  28.982201
# 2       CNU        CNU -95.485100  37.668800
# 3       CRS        CRS -96.400597  32.028099
# 4       FMY        FMY -81.863297  26.586599

# %%
df_airport_step4.count()
# Out:
# 2014

# %% [markdown]
# ##### Join

# %%
df_immigration_and_airport = df_immigration_step4.join(df_airport_step4, df_immigration_step4.i94port == df_airport_step4.iata_code, 'left_outer')

# %%
df_immigration_and_airport.limit(5).toPandas().head()
# Out:
#      cicid i94port     arrdate i94addr     depdate  i94bir  i94visa  biryear  \
# 0  5748517     LOS  2016-04-30      CA  2016-05-08      40        1     1976
# 1  3344386     NEW  2016-04-17      NJ  2016-04-25      67        2     1949
# 2  5748518     LOS  2016-04-30      NV  2016-05-17      32        1     1984
# 3  3344387     NEW  2016-04-17      NJ  2016-04-25      49        2     1967
# 4  5748519     LOS  2016-04-30      WA  2016-05-08      29        1     1987
#
#   gender airline    ...     elevation_ft continent iso_country  iso_region  \
# 0      F      QF    ...              NaN      None        None        None
# 1      M      UA    ...              8.0        NA          US       US-LA
# 2      F      VA    ...              NaN      None        None        None
# 3      F      UA    ...              8.0        NA          US       US-LA
# 4      M      DL    ...              NaN      None        None        None
#
#    municipality gps_code iata_code local_code   latitude longitude
# 0          None     None      None       None        NaN       NaN
# 1   New Orleans     KNEW       NEW        NEW -90.028297   30.0424
# 2          None     None      None       None        NaN       NaN
# 3   New Orleans     KNEW       NEW        NEW -90.028297   30.0424
# 4          None     None      None       None        NaN       NaN
#
# [5 rows x 28 columns]

# %%
df_immigration_and_airport.show()
# Out:
# +-------+-------+----------+-------+----------+------+-------+-------+------+-------+----------+-----+--------+-----+------+-----+--------------+--------------------+------------+---------+-----------+----------+------------+--------+---------+----------+--------+---------+
# |  cicid|i94port|   arrdate|i94addr|   depdate|i94bir|i94visa|biryear|gender|airline|    admnum|fltno|visatype|i94yr|i94mon|ident|          type|                name|elevation_ft|continent|iso_country|iso_region|municipality|gps_code|iata_code|local_code|latitude|longitude|
# +-------+-------+----------+-------+----------+------+-------+-------+------+-------+----------+-----+--------+-----+------+-----+--------------+--------------------+------------+---------+-----------+----------+------------+--------+---------+----------+--------+---------+
# |5748517|    LOS|2016-04-30|     CA|2016-05-08|    40|      1|   1976|     F|     QF|2147483647|00011|      B1| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344386|    NEW|2016-04-17|     NJ|2016-04-25|    67|      2|   1949|     M|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748518|    LOS|2016-04-30|     NV|2016-05-17|    32|      1|   1984|     F|     VA|2147483647|00007|      B1| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344387|    NEW|2016-04-17|     NJ|2016-04-25|    49|      2|   1967|     F|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748519|    LOS|2016-04-30|     WA|2016-05-08|    29|      1|   1987|     M|     DL|2147483647|00040|      B1| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344388|    NEW|2016-04-17|     NY|2016-04-19|    23|      2|   1993|     M|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748520|    LOS|2016-04-30|     WA|2016-05-14|    29|      1|   1987|     F|     DL|2147483647|00040|      B1| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344389|    NEW|2016-04-17|     NY|2016-04-23|    30|      2|   1986|     M|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748521|    LOS|2016-04-30|     WA|2016-05-14|    28|      1|   1988|     M|     DL|2147483647|00040|      B1| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344390|    NEW|2016-04-17|     NY|2016-04-23|    29|      2|   1987|     F|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748522|    HHW|2016-04-30|     HI|2016-05-05|    57|      2|   1959|     M|     NZ|2147483647|00010|      B2| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344391|    NEW|2016-04-17|     NY|2016-04-24|    52|      2|   1964|     M|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748523|    HHW|2016-04-30|     HI|2016-05-12|    66|      2|   1950|     F|     NZ|2147483647|00010|      B2| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344392|    NEW|2016-04-17|     NY|2016-04-24|    50|      2|   1966|     F|     UA|2147483647|00865|      WT| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748524|    HHW|2016-04-30|     HI|2016-05-12|    41|      2|   1975|     F|     NZ|2147483647|00010|      B2| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344408|    NEW|2016-04-18|   null|2016-04-21|    45|      1|   1971|     M|     UA|2147483647|00148|      WB| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748525|    HOU|2016-04-30|     FL|2016-05-07|    27|      2|   1989|     M|     NZ|2147483647|00028|      B2| 2016|     4| KHOU| large_airport|William P Hobby A...|          46|       NA|         US|     US-TX|     Houston|    KHOU|      HOU|       HOU|-95.2789|  29.6454|
# |3344409|    NEW|2016-04-18|   null|2016-04-27|    47|      1|   1969|     F|     OS|2147483647|00089|      WB| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# |5748526|    LOS|2016-04-30|     CA|2016-05-07|    26|      2|   1990|     F|     NZ|2147483647|00002|      B2| 2016|     4| null|          null|                null|        null|     null|       null|      null|        null|    null|     null|      null|    null|     null|
# |3344411|    NEW|2016-04-18|     AL|2016-04-28|    58|      1|   1958|     M|     UA|2147483647|00865|      WB| 2016|     4| KNEW|medium_airport|   Lakefront Airport|           8|       NA|         US|     US-LA| New Orleans|    KNEW|      NEW|       NEW|-90.0283|  30.0424|
# +-------+-------+----------+-------+----------+------+-------+-------+------+-------+----------+-----+--------+-----+------+-----+--------------+--------------------+------------+---------+-----------+----------+------------+--------+---------+----------+--------+---------+
# only showing top 20 rows

# %%
df_immigration_and_airport.count()
# Out:
# 3096313

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %% [markdown]
# There are no duplicate keys.

# %%
df_immigration_and_airport.filter(df_immigration_and_airport['cicid'].isNull()).count()
# Out:
# 0

# %% [markdown]
# I94 Immigration Data and the number of final data matches.

# %%
df_immigration_and_airport.count()
# Out:
# 3096313

# %%
df_immigration_step4.count()
# Out:
# 3096313

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# - cicid: This is the unique Identifier(I94 Immigration Data)
# - i94port: 3 character code of destination city(I94 Immigration Data)
# - arrdate: Arrival date of the departure(I94 Immigration Data)
# - i94addr: State(I94 Immigration Data)
# - depdate: Departure date(I94 Immigration Data)
# - i94bir: Ages(I94 Immigration Data)
# - i94visa: Reason for immigration(I94 Immigration Data)
# - biryear: Birth year(I94 Immigration Data)
# - gender: Gender(I94 Immigration Data)
# - airline: Airline(I94 Immigration Data)
# - admnum: Admission Number(I94 Immigration Data)
# - fltno： Flight Number(I94 Immigration Data)
# - visatype: Visa type(Student, Job, etc.)(I94 Immigration Data)
# - i94yr: 4 digit year of the arrival(I94 Immigration Data)
# - i94mon: Numeric month of the arrival(I94 Immigration Data)
# - ident: The text identifier used in the OurAirports URL(Airport Code Table)
# - type: The type of the airport(Airport Code Table)
# - name: The official airport name, including "Airport", "Airstrip", etc.(Airport Code Table)
# - elevation_ft: The airport elevation MSL in feet (not metres).(Airport Code Table)
# - continent: The code for the continent where the airport is (primarily) located(Airport Code Table)
# - iso_country: The two-character ISO 3166:1-alpha2 code for the country where the airport is (primarily) located(Airport Code Table)
# - iso_region: An alphanumeric code for the high-level administrative subdivision of a country where the airport is primarily located(Airport Code Table)
# - municipality: The primary municipality that the airport serves (when available)(Airport Code Table)
# - gps_code: The code that an aviation GPS database (such as Jeppesen's or Garmin's) would normally use for the airport.(Airport Code Table)
# - iata_code: The three-letter IATA code for the airport (if it has one).(Airport Code Table)
# - local_code: The local country code for the airport, if different from the gps_code and iata_code fields (used mainly for US airports)(Airport Code Table)
# - latitude: Latitude(Airport Code Table)
# - longitude: Longitude(Airport Code Table)

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# 　* Spark is used to process large amounts of data quickly.
# * Propose how often the data should be updated and why.
#  * I94 Immigration Data can be updated when new data is published.
#  * The Airport Code Table needs to be updated when new airports are added.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#    -> Increase the number of nodes in SPARK to handle this.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#    -> Use a tool that allows for scheduled execution. For example, Apache Airflow.
#  * The database needed to be accessed by 100+ people.
#    -> Increase the number of nodes in SPARK to handle this.
